# %% [markdown]
# # Import libararies

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /Users/tobeychen/opt/anaconda3/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/tobeychen/opt/anaconda3/lib/python3.9/site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
import geopandas as gpd
import requests
import json

# %%
# Define your Google Maps API key
api_key = 'AIzaSyDz6spnv8njg-7mNSMY0HETwYOQzE5DDzI'

# Create a geocoder instance
geolocator = GoogleV3(api_key=api_key)

# %% [markdown]
# # 0: NSW

# %%
gdf_sa2 = gpd.read_file('SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.shp')
print(gdf_sa2.shape)
print(len(gdf_sa2))
gdf_sa2.head(3)
# Out:
# (2473, 17)
# 2473
#   SA2_CODE21  SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  SA3_NAME21  \
# 0  101021007   Braidwood          0  No change      10102  Queanbeyan
# 1  101021008     Karabar          0  No change      10102  Queanbeyan
# 2  101021009  Queanbeyan          0  No change      10102  Queanbeyan
#
#   SA4_CODE21      SA4_NAME21 GCC_CODE21   GCC_NAME21 STE_CODE21  \
# 0        101  Capital Region      1RNSW  Rest of NSW          1
# 1        101  Capital Region      1RNSW  Rest of NSW          1
# 2        101  Capital Region      1RNSW  Rest of NSW          1
#
#         STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 0  New South Wales        AUS  Australia   3418.3525
# 1  New South Wales        AUS  Australia      6.9825
# 2  New South Wales        AUS  Australia      4.7620
#
#                                           LOCI_URI21  \
# 0  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                             geometry
# 0  POLYGON ((149.58424 -35.44426, 149.58444 -35.4...
# 1  POLYGON ((149.21899 -35.36738, 149.21800 -35.3...
# 2  POLYGON ((149.21326 -35.34325, 149.21619 -35.3...

# %%
gdf_sua = gpd.read_file('SUA_2021_AUST_GDA2020_SHP/SUA_2021_AUST_GDA2020.shp')
print(gdf_sua.shape)
print(len(gdf_sua))
gdf_sua.head(3)
# Out:
# (112, 7)
# 112
#   SUA_CODE21                               SUA_NAME21 AUS_CODE21 AUS_NAME21  \
# 0       1000  Not in any Significant Urban Area (NSW)        AUS  Australia
# 1       1001                         Albury - Wodonga        AUS  Australia
# 2       1002                                 Armidale        AUS  Australia
#
#       AREASQKM                                         LOCI_URI21  \
# 0  786334.6808  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 1     628.2525  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 2     274.5996  https://linked.data.gov.au/dataset/asgsed3/SUA...
#
#                                             geometry
# 0  MULTIPOLYGON (((149.95503 -37.10869, 149.95488...
# 1  POLYGON ((147.09592 -36.04051, 147.09669 -36.0...
# 2  POLYGON ((151.66895 -30.43596, 151.66899 -30.4...

# %%
gdf_sua_sa2 = gpd.sjoin(gdf_sa2, gdf_sua)
print(gdf_sua_sa2.shape)
print(len(gdf_sua_sa2))
gdf_sua_sa2.head(3)
# Out:
# (542, 24)
# 542
#    SA2_CODE21            SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  \
# 11  101041017          Batemans Bay          0  No change      10104
# 12  101041018  Batemans Bay - South          0  No change      10104
# 15  101041021     Broulee - Tomakin          0  No change      10104
#
#      SA3_NAME21 SA4_CODE21      SA4_NAME21 GCC_CODE21   GCC_NAME21  ...  \
# 11  South Coast        101  Capital Region      1RNSW  Rest of NSW  ...
# 12  South Coast        101  Capital Region      1RNSW  Rest of NSW  ...
# 15  South Coast        101  Capital Region      1RNSW  Rest of NSW  ...
#
#    AREASQKM21                                    LOCI_URI21_left  \
# 11    63.7073  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 12    30.5948  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 15    24.2329  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                              geometry index_right  SUA_CODE21  \
# 11  POLYGON ((150.26267 -35.70079, 150.26255 -35.7...           3        1004
# 12  MULTIPOLYGON (((150.21194 -35.72520, 150.21192...           3        1004
# 15  MULTIPOLYGON (((150.16781 -35.83441, 150.17055...           3        1004
#
#       SUA_NAME21 AUS_CODE21_right  AUS_NAME21_right AREASQKM  \
# 11  Batemans Bay              AUS         Australia  94.3021
# 12  Batemans Bay              AUS         Australia  94.3021
# 15  Batemans Bay              AUS         Australia  94.3021
#
#                                      LOCI_URI21_right
# 11  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 12  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 15  https://linked.data.gov.au/dataset/asgsed3/SUA...
#
# [3 rows x 24 columns]

# %%
gdf_sua_sa2 = pd.merge(gdf_sua, gdf_sa2, 
                          left_on = 'SUA_NAME21', right_on = 'SA2_NAME21', how='left')

# or:
# gdf_population2 = gdf_sua.merge(df, 
#                            left_on = 'SUA_NAME21', right_on = 'SUA',
#                            how = 'right')

print(gdf_sua_sa2.shape)
print(len(gdf_sua_sa2))
gdf_sua_sa2
# Out:
# (31, 24)
# 31
#    SUA_CODE21                          SUA_NAME21 AUS_CODE21_x AUS_NAME21_x  \
# 0        1001                    Albury - Wodonga          AUS    Australia
# 1        1002                            Armidale          AUS    Australia
# 2        1003                             Ballina          AUS    Australia
# 3        1004                        Batemans Bay          AUS    Australia
# 4        1005                            Bathurst          AUS    Australia
# 5        1006                  Bowral - Mittagong          AUS    Australia
# 6        1007                         Broken Hill          AUS    Australia
# 7        1008                           Byron Bay          AUS    Australia
# 8        1009                        Camden Haven          AUS    Australia
# 9        1010                       Central Coast          AUS    Australia
# 10       1011                       Coffs Harbour          AUS    Australia
# 11       1012                               Dubbo          AUS    Australia
# 12       1013                  Forster - Tuncurry          AUS    Australia
# 13       1014                            Goulburn          AUS    Australia
# 14       1015                             Grafton          AUS    Australia
# 15       1017                             Kempsey          AUS    Australia
# 16       1018                             Lismore          AUS    Australia
# 17       1019                             Lithgow          AUS    Australia
# 18       1020                             Medowie          AUS    Australia
# 19       1021               Morisset - Cooranbong          AUS    Australia
# 20       1022                              Mudgee          AUS    Australia
# 21       1023                        Muswellbrook          AUS    Australia
# 22       1024                          Nelson Bay          AUS    Australia
# 23       1026                   Nowra - Bomaderry          AUS    Australia
# 24       1028                      Port Macquarie          AUS    Australia
# 25       1030  St Georges Basin - Sanctuary Point          AUS    Australia
# 26       1031                              Sydney          AUS    Australia
# 27       1033                               Taree          AUS    Australia
# 28       1034                           Ulladulla          AUS    Australia
# 29       1035                         Wagga Wagga          AUS    Australia
# 30       1036                          Wollongong          AUS    Australia
#
#      AREASQKM                                       LOCI_URI21_x  \
# 0    628.2525  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 1    274.5996  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 2    480.5548  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 3     94.3021  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 4    213.5388  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 5    421.8192  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 6    170.1153  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 7     39.7771  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 8    524.9062  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 9   1334.2426  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 10   505.5228  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 11   182.5608  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 12    49.5428  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 13    64.7865  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 14   106.2537  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 15   195.1561  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 16    88.5366  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 17   119.9844  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 18   365.1820  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 19   340.6800  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 20    65.8949  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 21   262.3964  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 22   115.5262  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 23   201.4117  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 24    96.2548  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 25   107.8711  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 26  4196.8372  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 27   186.6495  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 28    46.7765  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 29   192.0954  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 30   572.6371  https://linked.data.gov.au/dataset/asgsed3/SUA...
#
#                                            geometry_x SA2_CODE21  \
# 0   POLYGON ((147.09592 -36.04051, 147.09669 -36.0...        NaN
# 1   POLYGON ((151.66895 -30.43596, 151.66899 -30.4...  110011186
# 2   MULTIPOLYGON (((153.56836 -28.89247, 153.56825...  112011236
# 3   MULTIPOLYGON (((150.21565 -35.74990, 150.21576...  101041017
# 4   POLYGON ((149.59755 -33.34829, 149.60318 -33.3...        NaN
# 5   POLYGON ((150.44074 -34.51298, 150.44081 -34.5...        NaN
# 6   POLYGON ((141.48304 -32.00248, 141.48150 -32.0...  105021097
# 7   MULTIPOLYGON (((153.61882 -28.72292, 153.61881...  112011240
# 8   POLYGON ((152.80862 -31.67726, 152.80860 -31.6...        NaN
# 9   MULTIPOLYGON (((151.20449 -33.53280, 151.20448...        NaN
# 10  MULTIPOLYGON (((153.07639 -30.42982, 153.07645...        NaN
# 11  POLYGON ((148.62083 -32.19588, 148.62093 -32.1...        NaN
# 12  POLYGON ((152.51231 -32.24303, 152.51222 -32.2...        NaN
# 13  POLYGON ((149.76305 -34.75207, 149.76205 -34.7...  101051539
# 14  POLYGON ((152.94597 -29.69937, 152.94640 -29.6...  104011080
# 15  POLYGON ((152.82162 -31.04639, 152.82163 -31.0...  108021155
# 16  POLYGON ((153.31668 -28.86111, 153.31700 -28.8...  112021248
# 17  POLYGON ((150.14683 -33.51861, 150.14621 -33.5...  103031070
# 18  MULTIPOLYGON (((151.97842 -32.70406, 151.97841...        NaN
# 19  POLYGON ((151.52585 -33.14187, 151.52580 -33.1...  111021218
# 20  POLYGON ((149.62289 -32.60054, 149.62304 -32.6...  103031072
# 21  POLYGON ((150.90012 -32.21620, 150.90035 -32.2...  106041126
# 22  MULTIPOLYGON (((152.07987 -32.78985, 152.07970...        NaN
# 23  POLYGON ((150.60444 -34.92475, 150.60431 -34.9...        NaN
# 24  MULTIPOLYGON (((152.91942 -31.42896, 152.91972...        NaN
# 25  POLYGON ((150.67543 -35.05769, 150.67545 -35.0...        NaN
# 26  MULTIPOLYGON (((151.15818 -34.08641, 151.15817...        NaN
# 27  POLYGON ((152.54907 -31.90734, 152.54848 -31.9...  108051169
# 28  POLYGON ((150.48036 -35.35311, 150.48027 -35.3...  114011282
# 29  POLYGON ((147.34773 -35.09482, 147.34771 -35.0...        NaN
# 30  MULTIPOLYGON (((150.87680 -34.54497, 150.87642...        NaN
#
#                SA2_NAME21 CHG_FLAG21  ...                         SA4_NAME21  \
# 0                     NaN        NaN  ...                                NaN
# 1                Armidale          0  ...         New England and North West
# 2                 Ballina          0  ...                   Richmond - Tweed
# 3            Batemans Bay          0  ...                     Capital Region
# 4                     NaN        NaN  ...                                NaN
# 5                     NaN        NaN  ...                                NaN
# 6             Broken Hill          0  ...                 Far West and Orana
# 7               Byron Bay          0  ...                   Richmond - Tweed
# 8                     NaN        NaN  ...                                NaN
# 9                     NaN        NaN  ...                                NaN
# 10                    NaN        NaN  ...                                NaN
# 11                    NaN        NaN  ...                                NaN
# 12                    NaN        NaN  ...                                NaN
# 13               Goulburn          0  ...                     Capital Region
# 14                Grafton          0  ...            Coffs Harbour - Grafton
# 15                Kempsey          0  ...                    Mid North Coast
# 16                Lismore          0  ...                   Richmond - Tweed
# 17                Lithgow          0  ...                       Central West
# 18                    NaN        NaN  ...                                NaN
# 19  Morisset - Cooranbong          0  ...       Newcastle and Lake Macquarie
# 20                 Mudgee          0  ...                       Central West
# 21           Muswellbrook          0  ...        Hunter Valley exc Newcastle
# 22                    NaN        NaN  ...                                NaN
# 23                    NaN        NaN  ...                                NaN
# 24                    NaN        NaN  ...                                NaN
# 25                    NaN        NaN  ...                                NaN
# 26                    NaN        NaN  ...                                NaN
# 27                  Taree          0  ...                    Mid North Coast
# 28              Ulladulla          0  ...  Southern Highlands and Shoalhaven
# 29                    NaN        NaN  ...                                NaN
# 30                    NaN        NaN  ...                                NaN
#
#    GCC_CODE21   GCC_NAME21 STE_CODE21       STE_NAME21 AUS_CODE21_y  \
# 0         NaN          NaN        NaN              NaN          NaN
# 1       1RNSW  Rest of NSW          1  New South Wales          AUS
# 2       1RNSW  Rest of NSW          1  New South Wales          AUS
# 3       1RNSW  Rest of NSW          1  New South Wales          AUS
# 4         NaN          NaN        NaN              NaN          NaN
# 5         NaN          NaN        NaN              NaN          NaN
# 6       1RNSW  Rest of NSW          1  New South Wales          AUS
# 7       1RNSW  Rest of NSW          1  New South Wales          AUS
# 8         NaN          NaN        NaN              NaN          NaN
# 9         NaN          NaN        NaN              NaN          NaN
# 10        NaN          NaN        NaN              NaN          NaN
# 11        NaN          NaN        NaN              NaN          NaN
# 12        NaN          NaN        NaN              NaN          NaN
# 13      1RNSW  Rest of NSW          1  New South Wales          AUS
# 14      1RNSW  Rest of NSW          1  New South Wales          AUS
# 15      1RNSW  Rest of NSW          1  New South Wales          AUS
# 16      1RNSW  Rest of NSW          1  New South Wales          AUS
# 17      1RNSW  Rest of NSW          1  New South Wales          AUS
# 18        NaN          NaN        NaN              NaN          NaN
# 19      1RNSW  Rest of NSW          1  New South Wales          AUS
# 20      1RNSW  Rest of NSW          1  New South Wales          AUS
# 21      1RNSW  Rest of NSW          1  New South Wales          AUS
# 22        NaN          NaN        NaN              NaN          NaN
# 23        NaN          NaN        NaN              NaN          NaN
# 24        NaN          NaN        NaN              NaN          NaN
# 25        NaN          NaN        NaN              NaN          NaN
# 26        NaN          NaN        NaN              NaN          NaN
# 27      1RNSW  Rest of NSW          1  New South Wales          AUS
# 28      1RNSW  Rest of NSW          1  New South Wales          AUS
# 29        NaN          NaN        NaN              NaN          NaN
# 30        NaN          NaN        NaN              NaN          NaN
#
#    AUS_NAME21_y AREASQKM21                                       LOCI_URI21_y  \
# 0           NaN        NaN                                                NaN
# 1     Australia   274.5996  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2     Australia    36.1602  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 3     Australia    63.7073  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 4           NaN        NaN                                                NaN
# 5           NaN        NaN                                                NaN
# 6     Australia   170.1153  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 7     Australia    39.7771  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 8           NaN        NaN                                                NaN
# 9           NaN        NaN                                                NaN
# 10          NaN        NaN                                                NaN
# 11          NaN        NaN                                                NaN
# 12          NaN        NaN                                                NaN
# 13    Australia    64.7865  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 14    Australia   106.2537  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 15    Australia   195.1561  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 16    Australia    63.3097  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 17    Australia   119.9844  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 18          NaN        NaN                                                NaN
# 19    Australia   330.5207  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 20    Australia    65.8949  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 21    Australia   262.3964  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 22          NaN        NaN                                                NaN
# 23          NaN        NaN                                                NaN
# 24          NaN        NaN                                                NaN
# 25          NaN        NaN                                                NaN
# 26          NaN        NaN                                                NaN
# 27    Australia   125.1186  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 28    Australia    46.7765  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 29          NaN        NaN                                                NaN
# 30          NaN        NaN                                                NaN
#
#                                            geometry_y
# 0                                                None
# 1   POLYGON ((151.58534 -30.50991, 151.58588 -30.5...
# 2   MULTIPOLYGON (((153.57106 -28.87381, 153.57106...
# 3   POLYGON ((150.26267 -35.70079, 150.26255 -35.7...
# 4                                                None
# 5                                                None
# 6   POLYGON ((141.41403 -31.93875, 141.41404 -31.9...
# 7   MULTIPOLYGON (((153.62192 -28.70596, 153.62200...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  POLYGON ((149.68790 -34.75152, 149.68809 -34.7...
# 14  POLYGON ((152.89877 -29.66367, 152.89870 -29.6...
# 15  POLYGON ((152.73696 -31.07374, 152.73714 -31.0...
# 16  POLYGON ((153.25828 -28.80043, 153.25836 -28.7...
# 17  POLYGON ((150.06828 -33.48443, 150.06828 -33.4...
# 18                                               None
# 19  POLYGON ((151.35183 -33.04299, 151.35205 -33.0...
# 20  POLYGON ((149.61397 -32.58835, 149.61470 -32.5...
# 21  POLYGON ((150.86063 -32.27452, 150.86061 -32.2...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27  POLYGON ((152.44017 -31.90745, 152.44012 -31.9...
# 28  POLYGON ((150.42481 -35.32416, 150.42513 -35.3...
# 29                                               None
# 30                                               None
#
# [31 rows x 24 columns]

# %% [markdown]
# Filter the city in NSW

# %%
def get_state_from_city(city):
    location = geolocator.geocode(city, exactly_one=True)
    if location:
        if location.raw['address_components']:
            if (len(location.raw['address_components']) > 1):
                if (location.raw['address_components'][1]['types']):
                    if (location.raw['address_components'][1]['types'][0] == 'administrative_area_level_1'):
                        return location.raw['address_components'][1]['short_name']
                    elif (location.raw['address_components'][1]['types'][0] == 'administrative_area_level_2'):
                        return location.raw['address_components'][2]['short_name']
                    else:
                        return None
                else:
                    return None
            else:
                return None
        else:
            return None
    else:
        return None

# %%
for index, row in gdf_sua.iterrows():
    if (get_state_from_city(row['SUA_NAME21'].split(' - ')[0]) != 'NSW'):
        gdf_sua.drop(index, inplace=True)

# Reset the index of the DataFrame
gdf_sua = gdf_sua.reset_index(drop=True)

print(len(gdf_sua))
gdf_sua.head()
# Out:
# 31
#   SUA_CODE21        SUA_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM  \
# 0       1001  Albury - Wodonga        AUS  Australia  628.2525
# 1       1002          Armidale        AUS  Australia  274.5996
# 2       1003           Ballina        AUS  Australia  480.5548
# 3       1004      Batemans Bay        AUS  Australia   94.3021
# 4       1005          Bathurst        AUS  Australia  213.5388
#
#                                           LOCI_URI21  \
# 0  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 1  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 2  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 3  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 4  https://linked.data.gov.au/dataset/asgsed3/SUA...
#
#                                             geometry
# 0  POLYGON ((147.09592 -36.04051, 147.09669 -36.0...
# 1  POLYGON ((151.66895 -30.43596, 151.66899 -30.4...
# 2  MULTIPOLYGON (((153.56836 -28.89247, 153.56825...
# 3  MULTIPOLYGON (((150.21565 -35.74990, 150.21576...
# 4  POLYGON ((149.59755 -33.34829, 149.60318 -33.3...

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2[gdf_sa2['STE_NAME21'] == 'New South Wales'].plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua.plot(color = '#48CAE4', edgecolor = 'black', linewidth = 0.5, ax = ax)
plt.title('SAU in the NSW', fontsize = 15)

plt.show()

# %% [markdown]
# # 1: Elderly Pupolation rank

# %% [markdown]
# Get data for the population by 5-year group in SUA

# %%
df_population = pd.read_csv('Cleaned_Age_in_Five_Year_Groups_in_SUA.csv', header = 0, names = ['city', '0_4years','5_9years','10_14years', '15_19years', '20_24years', '25_29years', '30_34years', '35_39years', '40_44years', '45_49years', '50_54years', '55_59years', '60_64years', '65_69years', '70_74years', '75_79years', '80_84years', '85_89years', '90_94years', '95_99years', '100years_and_over', 'total']);
# df

# %%
# mask is a boolean array
mask = ~df_population['city'].isin(gdf_sua['SUA_NAME21'])

df_population = df_population.loc[~mask]

# Reset the index of the DataFrame
df_population = df_population.reset_index(drop=True)

print(len(gdf_sua))
df_population.head()
# Out:
# 31
#                city  0_4years  5_9years  10_14years  15_19years  20_24years  \
# 0            Sydney    289412    304234      296045      270956      321649
# 1  Albury - Wodonga      6185      6501        6201        6009        5973
# 2          Armidale      1315      1422        1536        2028        2111
# 3           Ballina      2196      2519        2798        2416        1877
# 4      Batemans Bay       756       819         998         837         641
#
#    25_29years  30_34years  35_39years  40_44years  ...  60_64years  \
# 0      372066      394857      389136      340534  ...      249922
# 1        6542        6551        6289        5830  ...        5797
# 2        1701        1553        1439        1188  ...        1318
# 3        1945        2317        2588        2647  ...        3369
# 4         720         729         756         799  ...        1539
#
#    65_69years  70_74years  75_79years  80_84years  85_89years  90_94years  \
# 0      210802      182229      130226       90623       56049       28796
# 1        5531        4865        3454        2372        1331         687
# 2        1167        1090         890         652         387         176
# 3        3484        3215        2306        1648        1053         594
# 4        1571        1614        1109         691         415         193
#
#    95_99years  100years_and_over    total
# 0        8400               1069  4830047
# 1         186                 23    97793
# 2          38                  4    23967
# 3         174                 25    46190
# 4          53                  5    17524
#
# [5 rows x 23 columns]

# %%
df_population.loc[:, '65years_and_over'] = (df_population['65_69years'] + df_population['70_74years'] + df_population['75_79years'] + df_population['80_84years'] + df_population['85_89years'] + df_population['90_94years'] + df_population['95_99years'] + df_population['100years_and_over'])

df_population = df_population.drop(columns=['0_4years','5_9years','10_14years', '15_19years', '20_24years', '25_29years', '30_34years', '35_39years', '40_44years', '45_49years', '50_54years', '55_59years', '60_64years', '65_69years', '70_74years', '75_79years', '80_84years', '85_89years', '90_94years', '95_99years', '100years_and_over'
])

df_population = df_population.loc[:, ['city', '65years_and_over', 'total']]
df_population['elderly_ratio'] = df_population['65years_and_over'] / df_population['total']
df_population.head()
# Out:
#                city  65years_and_over    total  elderly_ratio
# 0            Sydney            708194  4830047       0.146623
# 1  Albury - Wodonga             18449    97793       0.188654
# 2          Armidale              4404    23967       0.183753
# 3           Ballina             12499    46190       0.270600
# 4      Batemans Bay              5651    17524       0.322472

# %% [markdown]
# ## 1-1: Rank for total population

# %% [markdown]
# Bar comparison

# %%
plt.bar(df_population['city'], df_population['total'])

plt.xticks(rotation=90)
plt.show()

# %%
gdf_sua_population = pd.merge(gdf_sua, df_population, 
                          left_on = 'SUA_NAME21', right_on = 'city',
                          how = 'right')
print(len(gdf_sua_population))
gdf_sua_population.head(3)
# Out:
#   SUA_CODE21        SUA_NAME21 AUS_CODE21 AUS_NAME21   AREASQKM  \
# 0       1031            Sydney        AUS  Australia  4196.8372
# 1       1001  Albury - Wodonga        AUS  Australia   628.2525
# 2       1002          Armidale        AUS  Australia   274.5996
#
#                                           LOCI_URI21  \
# 0  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 1  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 2  https://linked.data.gov.au/dataset/asgsed3/SUA...
#
#                                             geometry              city  \
# 0  MULTIPOLYGON (((151.15818 -34.08641, 151.15817...            Sydney
# 1  POLYGON ((147.09592 -36.04051, 147.09669 -36.0...  Albury - Wodonga
# 2  POLYGON ((151.66895 -30.43596, 151.66899 -30.4...          Armidale
#
#    65years_and_over    total  elderly_ratio
# 0            708194  4830047       0.146623
# 1             18449    97793       0.188654
# 2              4404    23967       0.183753

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2[gdf_sa2['STE_NAME21'] == 'New South Wales'].plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua_population.plot(column = 'total', edgecolor = 'black', cmap = 'rainbow', linewidth = 1, legend = True, ax = ax)

plt.title('SUAs in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'SUAs in NSW')

# %%
df_population = df_population.sort_values('total', ascending = False)

# reset index after sorting
df_population = df_population.reset_index(drop = True)

# create a new column 'Total_Rank'
df_population['total_rank'] = df_population.index + 1

# calculate the log value
df_population['total_population_log'] = np.log10(df_population['total']) 
df_population['total_rank_log'] = np.log10(df_population['total_rank'])
print(len(df_population))
df_population.head()
# Out:
# 31
#                city  65years_and_over    total  elderly_ratio  total_rank  \
# 0            Sydney            708194  4830047       0.146623           1
# 1     Central Coast             76357   343180       0.222498           2
# 2        Wollongong             58077   305691       0.189986           3
# 3  Albury - Wodonga             18449    97793       0.188654           4
# 4     Coffs Harbour             17419    74195       0.234773           5
#
#    total_population_log  total_rank_log  elderly_rank  elderly_population_log  \
# 0              6.683951        0.000000             1                5.850152
# 1              5.535522        0.301030             2                4.882849
# 2              5.485283        0.477121             3                4.764004
# 3              4.990308        0.602060             4                4.265973
# 4              4.870375        0.698970             5                4.241023
#
#    elderly_rank_log  elderly_ratio_rank  elderly_ratio_population_log  \
# 0          0.000000                  30                     -0.833799
# 1          0.301030                  17                     -0.652673
# 2          0.477121                  21                     -0.721278
# 3          0.602060                  22                     -0.724335
# 4          0.698970                  14                     -0.629351
#
#    elderly_ratio_rank_log
# 0                1.477121
# 1                1.230449
# 2                1.322219
# 3                1.342423
# 4                1.146128

# %%
# least squares polynomial fit
model = np.polyfit(df_population['total_population_log'], df_population['total_rank_log'], 1)
print(model)
# Out:
# [-0.66317785  4.1150049 ]

# %%
sns.regplot(data = df_population, x = df_population['total_population_log'], y = df_population['total_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %% [markdown]
# ## 1-2: Rank for elderly population

# %% [markdown]
# Get the total for age over 65

# %%
df_population = df_population.sort_values('65years_and_over', ascending = False)

# reset index after sorting
df_population = df_population.reset_index(drop = True)

# create a new column 'Elderly_Rank'
df_population['elderly_rank'] = df_population.index + 1

# calculate the log value
df_population['elderly_population_log'] = np.log10(df_population['65years_and_over']) 
df_population['elderly_rank_log'] = np.log10(df_population['elderly_rank'])
df_population.head()
# Out:
#                city  65years_and_over    total  elderly_ratio  total_rank  \
# 0            Sydney            708194  4830047       0.146623           1
# 1     Central Coast             76357   343180       0.222498           2
# 2        Wollongong             58077   305691       0.189986           3
# 3  Albury - Wodonga             18449    97793       0.188654           4
# 4     Coffs Harbour             17419    74195       0.234773           5
#
#    total_population_log  total_rank_log  elderly_rank  elderly_population_log  \
# 0              6.683951        0.000000             1                5.850152
# 1              5.535522        0.301030             2                4.882849
# 2              5.485283        0.477121             3                4.764004
# 3              4.990308        0.602060             4                4.265973
# 4              4.870375        0.698970             5                4.241023
#
#    elderly_rank_log
# 0          0.000000
# 1          0.301030
# 2          0.477121
# 3          0.602060
# 4          0.698970

# %% [markdown]
# Bar comparison

# %%
plt.bar(df_population['city'], df_population['65years_and_over'])

plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2[gdf_sa2['STE_NAME21'] == 'New South Wales'].plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua_population.plot(column = '65years_and_over', edgecolor = 'black', cmap = 'rainbow', linewidth = 1, legend = True, ax = ax)

plt.title('SUAs in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'SUAs in NSW')

# %%
# least squares polynomial fit
model = np.polyfit(df_population['elderly_rank_log'], df_population['elderly_population_log'], 1)
print(model)
# Out:
# [-1.32435296  5.36492584]

# %%
sns.regplot(data = df_population, x = df_population['elderly_population_log'], y = df_population['elderly_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %% [markdown]
# ## 1-3 Elderly Population vs Total Population

# %%
df_population = df_population.sort_values('elderly_ratio', ascending = False)

# # reset index after sorting
df_population = df_population.reset_index(drop = True)

# # create a new column 'elderly_ratio_rank'
df_population['elderly_ratio_rank'] = df_population.index + 1

# # calculate the log value
df_population['elderly_ratio_population_log'] = np.log10(df_population['elderly_ratio']) 
df_population['elderly_ratio_rank_log'] = np.log10(df_population['elderly_ratio_rank'])
df_population.head(3)
# Out:
#                  city  65years_and_over  total  elderly_ratio  total_rank  \
# 0  Forster - Tuncurry              8514  21087       0.403756          19
# 1        Camden Haven              7030  18484       0.380329          22
# 2          Nelson Bay              9640  28418       0.339222          14
#
#    total_population_log  total_rank_log  elderly_rank  elderly_population_log  \
# 0              4.324015        1.278754            11                3.930134
# 1              4.266796        1.342423            15                3.846955
# 2              4.453594        1.146128            10                3.984077
#
#    elderly_rank_log  elderly_ratio_rank  elderly_ratio_population_log  \
# 0          1.041393                   1                     -0.393881
# 1          1.176091                   2                     -0.419841
# 2          1.000000                   3                     -0.469516
#
#    elderly_ratio_rank_log
# 0                0.000000
# 1                0.301030
# 2                0.477121

# %%
plt.bar(df_population['city'], df_population['elderly_ratio'])

plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2[gdf_sa2['STE_NAME21'] == 'New South Wales'].plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua_population.plot(column = 'elderly_ratio', edgecolor = 'black', cmap = 'rainbow', linewidth = 1, legend = True, ax = ax)

plt.title('SUAs in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'SUAs in NSW')

# %%
# least squares polynomial fit
model = np.polyfit(df_population['elderly_ratio_rank_log'], df_population['elderly_ratio_population_log'], 1)
print(model)
# Out:
# [-0.30307118 -0.30768692]

# %%
sns.regplot(data = df_population, x = df_population['elderly_ratio_population_log'], y = df_population['elderly_ratio_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %% [markdown]
# ## 2: Social facilities rank

# %% [markdown]
# Get hospital list from https://www.health.gov.au/resources/publications/list-of-declared-hospitals

# %%
df_hospital = pd.read_excel('list-of-declared-hospitals.xlsx', header = 0, names = ['type', 'state', 'name', 'provider_number', 'address', 'suburb', 'Postcode', 'Second-tier Eligible', 'Second-tier Expiry Date', 'Second-tier Category', 'Circular_#', 'neo-natal_facility']);
df_hospital = df_hospital.loc[df_hospital['state'] == 'NSW']
df_hospital = df_hospital.drop(columns=['type', 'state', 'name', 'provider_number', 'suburb', 'Postcode', 'Second-tier Eligible', 'Second-tier Expiry Date', 'Second-tier Category', 'Circular_#', 'neo-natal_facility'])
df_hospital = df_hospital.reset_index(drop = True)
df_hospital.head()
# Out:
#                  address
# 0   14 KENSINGTON STREET
# 1          4 BAKER COURT
# 2       201 BORELLA ROAD
# 3  1125 PEMBERTON STREET
# 4       15 BOWDEN STREET

# %%
def get_coordinates(address):
    location = geolocator.geocode(address)
    if location:
        return pd.Series([location.latitude, location.longitude])
    else:
        return pd.Series([None, None])

# %%
df_hospital[['lat', 'lon']] = df_hospital['address'].apply(lambda x: get_coordinates(x))
print(len(df_hospital))
print(df_hospital.head())
# Out:
# 419
#                  address        lat         lon
# 0   14 KENSINGTON STREET -33.965202  151.134877
# 1          4 BAKER COURT  40.597530  -73.653075
# 2       201 BORELLA ROAD -36.077223  146.938523
# 3  1125 PEMBERTON STREET -36.074120  146.896020
# 4       15 BOWDEN STREET -33.904791  151.196103

# %% [markdown]
# https://wiki.openstreetmap.org/wiki/Key:amenity#Healthcare
#
# https://www.openstreetmap.org/relation/2316593
#
# area["ISO3166-2"="AU-NSW"][admin_level=4] is the same as area(3602316593)

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="clinic"](area);
 way["amenity"="clinic"](area);
 rel["amenity"="clinic"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
clinics = data['elements']
print(len(clinics))
# Out:
# 263

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="dentist"](area);
 way["amenity"="dentist"](area);
 rel["amenity"="dentist"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
dentists = data['elements']
print(len(dentists))
# Out:
# 273

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="nursing_home"](area);
 way["amenity"="nursing_home"](area);
 rel["amenity"="nursing_home"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
nursing_homes = data['elements']
len(data)
# Out:
# 4

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="pharmacy"](area);
 way["amenity"="pharmacy"](area);
 rel["amenity"="pharmacy"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
pharmacys = data['elements']
print(len(pharmacys))
# Out:
# 682

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="social_facility"](area);
 way["amenity"="social_facility"](area);
 rel["amenity"="social_facility"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
social_facilities = data['elements']
print(len(social_facilities))
# Out:
# 103

# %%
other_healthcare = clinics + dentists + nursing_homes + pharmacys + social_facilities
print(len(other_healthcare))
# Out:
# 1340

# %% [markdown]
# # other_healthcare

# %%
df_hospital = df_hospital.drop(columns=['address'])
df_hospital.head()
# Out:
#          lat         lon
# 0 -33.965202  151.134877
# 1  40.597530  -73.653075
# 2 -36.077223  146.938523
# 3 -36.074120  146.896020
# 4 -33.904791  151.196103

# %%
# import requests

# def get_aged_care_services(state):
#     url = f"https://www.myagedcare.gov.au/api/provider-search/in-home-aged-care?sort=alphabetical&state={state}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         data = response.json()
#         services = data.get('providers', [])
#         return services
#     else:
#         return None

# # Example usage
# state = 'NSW'
# aged_care_services = get_aged_care_services(state)
# if aged_care_services:
#     for service in aged_care_services:
#         # Process and print service details as needed
#         print(service)
# else:
#     print("Failed to retrieve aged care services.")

# %%
rows = [{'lat': item['lat'], 'lon': item['lon']} for item in other_healthcare]

# Create a DataFrame from the extracted values
df_all_healthcare = pd.DataFrame(rows)
print(len(df_all_healthcare))
df_all_healthcare.head()
# Out:
# 1340
#          lat         lon
# 0 -33.889157  151.275200
# 1 -33.889556  151.271111
# 2 -33.888995  151.270199
# 3 -33.829431  151.218038
# 4 -33.751564  151.287806

# %%
df_all_healthcare = pd.concat([df_all_healthcare, df_hospital], ignore_index=True)
print(len(df_all_healthcare))
df_all_healthcare.head()
# Out:
# 1759
#          lat         lon
# 0 -33.889157  151.275200
# 1 -33.889556  151.271111
# 2 -33.888995  151.270199
# 3 -33.829431  151.218038
# 4 -33.751564  151.287806

# %%
df_all_healthcare = df_all_healthcare.drop_duplicates(subset=['lat', 'lon'])
print(len(df_all_healthcare))
df_all_healthcare.head()
# Out:
# 1700
#          lat         lon
# 0 -33.889157  151.275200
# 1 -33.889556  151.271111
# 2 -33.888995  151.270199
# 3 -33.829431  151.218038
# 4 -33.751564  151.287806

# %%
gdf_all_healthcare = gpd.GeoDataFrame(df_all_healthcare,
                               geometry = gpd.points_from_xy(df_all_healthcare.lon, df_all_healthcare.lat))

gdf_all_healthcare.to_file('HealthcareLocationInNSW.geojson', driver='GeoJSON')

# %%
gdf_all_healthcare = gpd.read_file('HealthcareLocationInNSW.geojson')
print(len(gdf_all_healthcare))
gdf_all_healthcare.head(3)
# Out:
# 1700
#          lat         lon                     geometry
# 0 -33.889157  151.275200  POINT (151.27520 -33.88916)
# 1 -33.889556  151.271111  POINT (151.27111 -33.88956)
# 2 -33.888995  151.270199  POINT (151.27020 -33.88900)

# %%
gdf_all_healthcare = gdf_all_healthcare.to_crs(gdf_sua.crs)

print(gdf_all_healthcare.crs)
print(gdf_sua.crs)
# Out:
# EPSG:7844
# EPSG:7844

# %%
gdf_all_healthcare_GS = gpd.sjoin(gdf_all_healthcare, gdf_sua)

print(gdf_all_healthcare.shape)
print(gdf_sua.shape)
print(len(gdf_all_healthcare_GS))
gdf_all_healthcare_GS.head()
# Out:
# (1700, 3)
# (31, 7)
# 1199
#          lat         lon                     geometry  index_right SUA_CODE21  \
# 0 -33.889157  151.275200  POINT (151.27520 -33.88916)           26       1031
# 1 -33.889556  151.271111  POINT (151.27111 -33.88956)           26       1031
# 2 -33.888995  151.270199  POINT (151.27020 -33.88900)           26       1031
# 3 -33.829431  151.218038  POINT (151.21804 -33.82943)           26       1031
# 4 -33.751564  151.287806  POINT (151.28781 -33.75156)           26       1031
#
#   SUA_NAME21 AUS_CODE21 AUS_NAME21   AREASQKM  \
# 0     Sydney        AUS  Australia  4196.8372
# 1     Sydney        AUS  Australia  4196.8372
# 2     Sydney        AUS  Australia  4196.8372
# 3     Sydney        AUS  Australia  4196.8372
# 4     Sydney        AUS  Australia  4196.8372
#
#                                           LOCI_URI21
# 0  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 1  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 2  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 3  https://linked.data.gov.au/dataset/asgsed3/SUA...
# 4  https://linked.data.gov.au/dataset/asgsed3/SUA...

# %%
fig, ax = plt.subplots(figsize = (12,12))

gdf_sa2[gdf_sa2['STE_NAME21'] == 'New South Wales'].plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_all_healthcare_GS.plot(color = '#FF9300', markersize = 5, ax = ax, label = 'Healthcare')

plt.title('Healthcare in the NSW', fontsize = 15)
plt.legend(fontsize = 15)

plt.show()

# %% [markdown]
# Now we try to get the city for the coordinations

# %%
def get_city_from_coordinates(latitude, longitude):
    url = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={latitude},{longitude}&key={api_key}"
    response = requests.get(url)
    data = response.json()

    if data['status'] == 'OK':
        for result in data['results']:
            for component in result['address_components']:
                if 'locality' in component['types']:
                    return component['long_name']
    
    return None

# %%
for index, row in df_all_healthcare.iterrows():
    lat = row['lat']
    lon = row['lon']
    df_all_healthcare.loc[:, 'city'] = get_city_from_coordinates(lat, lon)
    
df_all_healthcare.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/0c/dq8xcgtn6_131w5cpccxn04h0000gn/T/ipykernel_67762/2413858409.py in <module>
#       2     lat = row['lat']
#       3     lon = row['lon']
# ----> 4     df_all_healthcare.loc[:, 'city'] = get_city_from_coordinates(lat, lon)
#       5
#       6 df_all_healthcare.head()
#
# /var/folders/0c/dq8xcgtn6_131w5cpccxn04h0000gn/T/ipykernel_67762/45062809.py in get_city_from_coordinates(latitude, longitude)
#       1 def get_city_from_coordinates(latitude, longitude):
#       2     url = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={latitude},{longitude}&key={api_key}"
# ----> 3     response = requests.get(url)
#       4     data = response.json()
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
