# %% [markdown]
# # Import libararies

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3

# %%
# Define your Google Maps API key
api_key = 'AIzaSyDz6spnv8njg-7mNSMY0HETwYOQzE5DDzI'

# Create a geocoder instance
geolocator = GoogleV3(api_key=api_key)

# %% [markdown]
# # 1: Elderly Pupolation rank

# %% [markdown]
# Get data for the population by 5-year group in SUA

# %%
df = pd.read_csv('Cleaned_Age_in_Five_Year_Groups_in_SUA.csv', header = 0, names = ['cities', '0-4_years','5-9_years','10-14_years', '15-19_years', '20-24_years', '25-29_years', '30-34_years', '35-39_years', '40-44_years', '45-49_years', '50-54_years', '55-59_years', '60-64_years', '65-69_years', '70-74_years', '75-79_years', '80-84_years', '85-89_years', '90-94_years', '95-99_years', '100_years_and_over', 'total']);
# df

# %% [markdown]
# Filter the SUA in NSW

# %%
def get_state_from_city(city):
    location = geolocator.geocode(city, exactly_one=True)
    if location:
        return location.raw['address_components'][2]['short_name']  # Extract the state name from the location information
    else:
        return None

# %%
df['state'] = df['cities'].apply(lambda x: get_state_from_city(x.split(' - ')[0]))
df = df.loc[df['state'] == 'NSW']
df
# Out:
#                                 cities  0-4_years  5-9_years  10-14_years  \
# 1                     Albury - Wodonga       6185       6501         6201
# 2                             Armidale       1315       1422         1536
# 4                         Batemans Bay        756        819          998
# 5                             Bathurst       2180       2421         2521
# 6                   Bowral - Mittagong       2125       2331         2660
# 8                            Byron Bay        477        503          513
# 9                         Camden Haven        590        842          966
# 10                       Central Coast      19278      20856        21609
# 11                       Coffs Harbour       3830       4480         4834
# 12                               Dubbo       3066       2887         2795
# 13                  Forster - Tuncurry        696        850          979
# 14                            Goulburn       1454       1534         1506
# ...

# %%
df.loc[:, '65_years_and_over_total'] = (
    df['65-69_years'] + df['70-74_years'] + df['75-79_years'] +
    df['80-84_years'] + df['85-89_years'] + df['90-94_years'] +
    df['95-99_years'] + df['100_years_and_over']
)

df = df.drop(columns=[
    '0-4_years', '5-9_years', '10-14_years', '15-19_years', '20-24_years',
    '25-29_years', '30-34_years', '35-39_years', '40-44_years', '45-49_years',
    '50-54_years', '55-59_years', '60-64_years', '65-69_years', '70-74_years',
    '75-79_years', '80-84_years', '85-89_years', '90-94_years', '95-99_years',
    '100_years_and_over'
])

df = df.loc[:, ['cities', '65_years_and_over_total', 'total', 'state']]

# %%
df = df.drop(columns=['state'])

# %% [markdown]
# ## 1-1: Rank for total population

# %%
df = df.sort_values('total', ascending = False)

# reset index after sorting
df = df.reset_index(drop = True)

# create a new column 'Total_Rank'
df['total_rank'] = df.index + 1

# calculate the log value
df['total_population_log'] = np.log10(df['total']) 
df['total_rank_log'] = np.log10(df['total_rank'])
df
# Out:
#                                 cities  65_years_and_over_total   total  \
# 0                        Central Coast                    76357  343180
# 1                           Wollongong                    58077  305691
# 2                     Albury - Wodonga                    18449   97793
# 3                        Coffs Harbour                    17419   74195
# 4                          Wagga Wagga                     9984   57003
# 5                       Port Macquarie                    14055   50193
# 6                   Bowral - Mittagong                    11502   41600
# 7                                Dubbo                     6691   40578
# 8                    Nowra - Bomaderry                     7958   38678
# 9                             Bathurst                     6764   37396
# 10                             Lismore                     5993   28816
# 11                          Nelson Bay                     9640   28418
# ...

# %%
# least squares polynomial fit
model = np.polyfit(df['total_population_log'], df['total_rank_log'], 1)
print(model)
# Out:
# [-0.94592974  5.28934293]

# %%
sns.regplot(data = df, x = df['total_population_log'], y = df['total_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %%
plt.bar(df['cities'], df['total'])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 1-2: Rank for elderly population

# %% [markdown]
# Get the total for age over 65

# %%
df = df.sort_values('65_years_and_over_total', ascending = False)

# reset index after sorting
df = df.reset_index(drop = True)

# create a new column 'Elderly_Rank'
df['elderly_rank'] = df.index + 1

# calculate the log value
df['elderly_population_log'] = np.log10(df['65_years_and_over_total']) 
df['elderly_rank_log'] = np.log10(df['elderly_rank'])
df
# Out:
#                                 cities  65_years_and_over_total   total  \
# 0                        Central Coast                    76357  343180
# 1                           Wollongong                    58077  305691
# 2                     Albury - Wodonga                    18449   97793
# 3                        Coffs Harbour                    17419   74195
# 4                       Port Macquarie                    14055   50193
# 5                   Bowral - Mittagong                    11502   41600
# 6                          Wagga Wagga                     9984   57003
# 7                           Nelson Bay                     9640   28418
# 8                   Forster - Tuncurry                     8514   21087
# 9                    Nowra - Bomaderry                     7958   38678
# 10               Morisset - Cooranbong                     7256   27828
# 11                               Taree                     7101   26519
# ...

# %%
# least squares polynomial fit
model = np.polyfit(df['elderly_rank_log'], df['elderly_population_log'], 1)
print(model)
# Out:
# [-1.0121067   4.90895097]

# %%
sns.regplot(data = df, x = df['elderly_population_log'], y = df['elderly_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %%
plt.bar(df['cities'], df['65_years_and_over_total'])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Elderly Population vs Total Population

# %%
df['elderly_ratio'] = df['total'] / df['65_years_and_over_total']
df = df.sort_values('elderly_ratio', ascending = False)

# # reset index after sorting
df = df.reset_index(drop = True)

# # create a new column 'elderly_ratio_rank'
df['elderly_ratio_rank'] = df.index + 1

# # calculate the log value
df['elderly_ratio_population_log'] = np.log10(df['elderly_ratio']) 
df['elderly_ratio_rank_log'] = np.log10(df['elderly_ratio_rank'])
df
# Out:
#                                 cities  65_years_and_over_total   total  \
# 0                         Muswellbrook                     1718   12272
# 1                                Dubbo                     6691   40578
# 2                            Byron Bay                     1876   10914
# 3                          Wagga Wagga                     9984   57003
# 4                             Bathurst                     6764   37396
# 5                              Medowie                     2754   15020
# 6                             Armidale                     4404   23967
# 7                               Mudgee                     2348   12563
# 8                     Albury - Wodonga                    18449   97793
# 9                           Wollongong                    58077  305691
# 10                   Nowra - Bomaderry                     7958   38678
# 11                             Lismore                     5993   28816
# ...

# %%
# least squares polynomial fit
model = np.polyfit(df['elderly_ratio_rank_log'], df['elderly_ratio_population_log'], 1)
print(model)
# Out:
# [-0.28909114  0.93614546]

# %%
sns.regplot(data = df, x = df['elderly_ratio_population_log'], y = df['elderly_ratio_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %%
plt.bar(df['cities'], df['elderly_ratio'])

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 2: Social facilities rank

# %% [markdown]
# Get hospital list from https://www.health.gov.au/resources/publications/list-of-declared-hospitals

# %%
df_hospital = pd.read_csv('cleaned_list-of-declared-hospitals.csv', header = 0);
# df_hospital = df_hospital.loc[df_hospital['State'] == 'New South Wales' and df_hospital['Open/Closed'] == 'Open']
df_hospital

# %%
# import requests

# def get_aged_care_services(state):
#     url = f"https://www.myagedcare.gov.au/api/provider-search/in-home-aged-care?sort=alphabetical&state={state}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         data = response.json()
#         services = data.get('providers', [])
#         return services
#     else:
#         return None

# # Example usage
# state = 'NSW'
# aged_care_services = get_aged_care_services(state)
# if aged_care_services:
#     for service in aged_care_services:
#         # Process and print service details as needed
#         print(service)
# else:
#     print("Failed to retrieve aged care services.")

# %%
def get_coordinates(address, api_key):
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        return None

# Example usage
address = "1600 Amphitheatre Parkway, Mountain View, CA"
api_key = "YOUR_GOOGLE_API_KEY"
coordinates = get_coordinates(address, api_key)
if coordinates:
    latitude, longitude = coordinates
    print(f"Latitude: {latitude}, Longitude: {longitude}")
else:
    print("Unable to retrieve coordinates for the address.")

# %%
coords = []
for index, row in df_hospital.iterrows():
    print(row['Name'])
    lon = element['Longitude']
    lat = element['Latitude']
    
# for element in df_hospital:
#   if element['type'] == 'node':
#     lon = element['lon']
#     lat = element['lat']
#     coords.append((lon, lat))
#   elif 'center' in element:
#     lon = element['center']['lon']
#     lat = element['center']['lat']
#     coords.append((lon, lat))
# # Convert coordinates into numpy array
# X = np.array(coords)
# plt.plot(X[:, 0], X[:, 1], 'o')
# plt.title('hospital in AU-NSW')
# plt.xlabel('Longitude')
# plt.ylabel('Latitude')
# plt.axis('equal')
# plt.show()
# Out:
# Justice Health Services
# The Children's Hospital at Westmead
# Sydney Children's Hospital
# Sacred Heart Health Service
# St Vincent's Hospital [Darlinghurst]
# St Joseph's Hospital
# Balmain Hospital
# Canterbury Hospital
# Royal Prince Alfred Hospital
# Tresillian Care Centres
# Concord Repatriation Hospital
# Royal Prince Alfred Institute of Rheumatology & Orthopaedics
# Karitane
# Camden Hospital
# Fairfield Hospital
# Liverpool Hospital
# Campbelltown Hospital
# Bankstown Lidcombe Hospital
# Braeside Hospital
# Bowral Hospital
# Sydney Hospital / Sydney Eye Hospital
# Calvary Health Care - Sydney
# Gower Wilson Multi Purpose Service
# War Memorial Hospital
# Prince of Wales Hospital
# St George Hospital NSW
# Sutherland Hospital
# Royal Hospital for Women
# Bulli Hospital
# Coledale Hospital
# Kiama Hospital
# Milton Ulladulla Hospital
# Port Kembla Hospital
# Shoalhaven Hospital
# Wollongong Hospital
# Shellharbour Hospital
# Illawarra Mental Health Services
# ...
