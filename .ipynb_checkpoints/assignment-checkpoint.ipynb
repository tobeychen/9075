# %% [markdown]
# # Import libararies

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /Users/tobeychen/opt/anaconda3/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/tobeychen/opt/anaconda3/lib/python3.9/site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
import geopandas as gpd
import requests
import json

# %%
# Define your Google Maps API key
api_key = 'AIzaSyDz6spnv8njg-7mNSMY0HETwYOQzE5DDzI'

# Create a geocoder instance
geolocator = GoogleV3(api_key=api_key)

# %% [markdown]
# # 0: NSW

# %%
gdf_sa2 = gpd.read_file('SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.shp')
print(gdf_sa2.shape)
print(len(gdf_sa2))
gdf_sa2.head(3)
# Out:
# (2473, 17)
# 2473
#   SA2_CODE21  SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  SA3_NAME21  \
# 0  101021007   Braidwood          0  No change      10102  Queanbeyan
# 1  101021008     Karabar          0  No change      10102  Queanbeyan
# 2  101021009  Queanbeyan          0  No change      10102  Queanbeyan
#
#   SA4_CODE21      SA4_NAME21 GCC_CODE21   GCC_NAME21 STE_CODE21  \
# 0        101  Capital Region      1RNSW  Rest of NSW          1
# 1        101  Capital Region      1RNSW  Rest of NSW          1
# 2        101  Capital Region      1RNSW  Rest of NSW          1
#
#         STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 0  New South Wales        AUS  Australia   3418.3525
# 1  New South Wales        AUS  Australia      6.9825
# 2  New South Wales        AUS  Australia      4.7620
#
#                                           LOCI_URI21  \
# 0  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                             geometry
# 0  POLYGON ((149.58424 -35.44426, 149.58444 -35.4...
# 1  POLYGON ((149.21899 -35.36738, 149.21800 -35.3...
# 2  POLYGON ((149.21326 -35.34325, 149.21619 -35.3...

# %% [markdown]
# Filter the city in NSW

# %%
gdf_sa2_NSW = gdf_sa2[(gdf_sa2['STE_NAME21'] == 'New South Wales') & (gdf_sa2['geometry'].notna())]
print(gdf_sa2_NSW.shape)
print(len(gdf_sa2_NSW))
gdf_sa2_NSW.head(3)
# Out:
# (642, 17)
# 642
#   SA2_CODE21  SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  SA3_NAME21  \
# 0  101021007   Braidwood          0  No change      10102  Queanbeyan
# 1  101021008     Karabar          0  No change      10102  Queanbeyan
# 2  101021009  Queanbeyan          0  No change      10102  Queanbeyan
#
#   SA4_CODE21      SA4_NAME21 GCC_CODE21   GCC_NAME21 STE_CODE21  \
# 0        101  Capital Region      1RNSW  Rest of NSW          1
# 1        101  Capital Region      1RNSW  Rest of NSW          1
# 2        101  Capital Region      1RNSW  Rest of NSW          1
#
#         STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 0  New South Wales        AUS  Australia   3418.3525
# 1  New South Wales        AUS  Australia      6.9825
# 2  New South Wales        AUS  Australia      4.7620
#
#                                           LOCI_URI21  \
# 0  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                             geometry
# 0  POLYGON ((149.58424 -35.44426, 149.58444 -35.4...
# 1  POLYGON ((149.21899 -35.36738, 149.21800 -35.3...
# 2  POLYGON ((149.21326 -35.34325, 149.21619 -35.3...

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2.plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sa2_NSW.plot(color = '#48CAE4', edgecolor = 'black', linewidth = 0.5, ax = ax)
plt.title('NSW in AU', fontsize = 15)

plt.show()

# %% [markdown]
# # 1: Elderly Pupolation rank

# %% [markdown]
# Get data for the population by 5-year group in SUA

# %%
df_population = pd.read_csv('Cleaned_Age_in_Five_Year_Groups_in_SA2.csv', header = 0, names = ['city', '0_4years','5_9years','10_14years', '15_19years', '20_24years', '25_29years', '30_34years', '35_39years', '40_44years', '45_49years', '50_54years', '55_59years', '60_64years', '65_69years', '70_74years', '75_79years', '80_84years', '85_89years', '90_94years', '95_99years', '100years_and_over', 'total']);
print(len(df_population))
df_population.head(3)
# Out:
# 2472
#          city  0_4years  5_9years  10_14years  15_19years  20_24years  \
# 0   Braidwood       207       254         229         173         122
# 1     Karabar       526       530         566         490         515
# 2  Queanbeyan       669       587         482         433         689
#
#    25_29years  30_34years  35_39years  40_44years  ...  60_64years  \
# 0         172         192         246         202  ...         435
# 1         629         637         588         546  ...         513
# 2        1130        1238         903         740  ...         587
#
#    65_69years  70_74years  75_79years  80_84years  85_89years  90_94years  \
# 0         338         302         249         124          59          21
# 1         429         325         227         160          69          19
# 2         509         418         286         266         206         107
#
#    95_99years  100years_and_over  total
# 0           8                  0   4343
# 1          10                  0   8517
# 2          29                  4  11342
#
# [3 rows x 23 columns]

# %%
# mask is a boolean array
mask = ~df_population['city'].isin(gdf_sa2_NSW['SA2_NAME21'])

df_population = df_population.loc[~mask]

# Reset the index of the DataFrame
df_population = df_population.reset_index(drop=True)

print(len(df_population))
df_population.head()
# Out:
# 642
#                               city  0_4years  5_9years  10_14years  \
# 0                        Braidwood       207       254         229
# 1                          Karabar       526       530         566
# 2                       Queanbeyan       669       587         482
# 3                Queanbeyan - East       319       252         212
# 4  Queanbeyan West - Jerrabomberra       835       914         971
#
#    15_19years  20_24years  25_29years  30_34years  35_39years  40_44years  \
# 0         173         122         172         192         246         202
# 1         490         515         629         637         588         546
# 2         433         689        1130        1238         903         740
# 3         184         343         555         539         435         317
# 4         927         746         646         837         926         878
#
#    ...  60_64years  65_69years  70_74years  75_79years  80_84years  \
# 0  ...         435         338         302         249         124
# 1  ...         513         429         325         227         160
# 2  ...         587         509         418         286         266
# 3  ...         296         216         168         126          72
# 4  ...         663         452         366         196         129
#
#    85_89years  90_94years  95_99years  100years_and_over  total
# 0          59          21           8                  0   4343
# 1          69          19          10                  0   8517
# 2         206         107          29                  4  11342
# 3          39          17           3                  0   5085
# 4          61          16           4                  0  12744
#
# [5 rows x 23 columns]

# %%
df_population.loc[:, '65years_and_over'] = (df_population['65_69years'] + df_population['70_74years'] + df_population['75_79years'] + df_population['80_84years'] + df_population['85_89years'] + df_population['90_94years'] + df_population['95_99years'] + df_population['100years_and_over'])

df_population = df_population.drop(columns=['0_4years','5_9years','10_14years', '15_19years', '20_24years', '25_29years', '30_34years', '35_39years', '40_44years', '45_49years', '50_54years', '55_59years', '60_64years', '65_69years', '70_74years', '75_79years', '80_84years', '85_89years', '90_94years', '95_99years', '100years_and_over'
])

df_population = df_population.loc[:, ['city', '65years_and_over', 'total']]
df_population['elderly_ratio'] = np.where(df_population['total'] != 0, df_population['65years_and_over'] / df_population['total'], 0)

df_population = df_population.sort_values('total', ascending = False)

# reset index after sorting
df_population = df_population.reset_index(drop = True)

print(len(df_population))
df_population
# Out:
# 642
#                               city  65years_and_over  total  elderly_ratio
# 0       Lalor Park - Kings Langley              4029  25373       0.158791
# 1    South Hurstville - Blakehurst              4304  25259       0.170395
# 2             Charlestown - Dudley              4530  25254       0.179378
# 3                Schofields - East               952  25130       0.037883
# 4            Baulkham Hills - East              4031  24726       0.163027
# ..                             ...               ...    ...            ...
# 637         Port Kembla Industrial                 0      5       0.000000
# 638       Holsworthy Military Area                 0      5       0.000000
# 639              Rookwood Cemetery                 0      3       0.000000
# 640          Wollangambe - Wollemi                 0      0       0.000000
# 641                Centennial Park                 0      0       0.000000
#
# [642 rows x 4 columns]

# %% [markdown]
# ## 1-1: Rank for total population

# %% [markdown]
# Bar comparison

# %%
fig, ax = plt.subplots(figsize=(16,10))
plt.bar(df_population['city'], df_population['total'])

plt.xticks(rotation=90)
plt.show()

# %%
gdf_sua_population = pd.merge(gdf_sa2_NSW, df_population, 
                          left_on = 'SA2_NAME21', right_on = 'city',
                          how = 'right')
print(len(gdf_sua_population))
gdf_sua_population
# Out:
# 642
#     SA2_CODE21                     SA2_NAME21 CHG_FLAG21    CHG_LBL21  \
# 0    116011307     Lalor Park - Kings Langley          0    No change
# 1    119031374  South Hurstville - Blakehurst          0    No change
# 2    111011208           Charlestown - Dudley          0    No change
# 3    116021632              Schofields - East          1          New
# 4    115011290          Baulkham Hills - East          3  Name change
# ..         ...                            ...        ...          ...
# 637  107011133         Port Kembla Industrial          0    No change
# 638  123021439       Holsworthy Military Area          0    No change
# 639  125011475              Rookwood Cemetery          0    No change
# 640  103031075          Wollangambe - Wollemi          0    No change
# 641  118011342                Centennial Park          0    No change
#
#     SA3_CODE21               SA3_NAME21 SA4_CODE21  \
# 0        11601                Blacktown        116
# 1        11903               Hurstville        119
# 2        11101    Lake Macquarie - East        111
# 3        11602        Blacktown - North        116
# 4        11501           Baulkham Hills        115
# ..         ...                      ...        ...
# 637      10701      Dapto - Port Kembla        107
# 638      12302       Campbelltown (NSW)        123
# 639      12501                   Auburn        125
# 640      10303         Lithgow - Mudgee        103
# 641      11801  Eastern Suburbs - North        118
#
#                                  SA4_NAME21 GCC_CODE21      GCC_NAME21  ...  \
# 0                        Sydney - Blacktown      1GSYD  Greater Sydney  ...
# 1                 Sydney - Inner South West      1GSYD  Greater Sydney  ...
# 2              Newcastle and Lake Macquarie      1RNSW     Rest of NSW  ...
# 3                        Sydney - Blacktown      1GSYD  Greater Sydney  ...
# 4    Sydney - Baulkham Hills and Hawkesbury      1GSYD  Greater Sydney  ...
# ..                                      ...        ...             ...  ...
# 637                               Illawarra      1RNSW     Rest of NSW  ...
# 638               Sydney - Outer South West      1GSYD  Greater Sydney  ...
# 639                     Sydney - Parramatta      1GSYD  Greater Sydney  ...
# 640                            Central West      1RNSW     Rest of NSW  ...
# 641                Sydney - Eastern Suburbs      1GSYD  Greater Sydney  ...
#
#           STE_NAME21 AUS_CODE21 AUS_NAME21 AREASQKM21  \
# 0    New South Wales        AUS  Australia    11.7998
# 1    New South Wales        AUS  Australia     6.2406
# 2    New South Wales        AUS  Australia    22.2795
# 3    New South Wales        AUS  Australia    11.6638
# 4    New South Wales        AUS  Australia     8.3081
# ..               ...        ...        ...        ...
# 637  New South Wales        AUS  Australia    12.9390
# 638  New South Wales        AUS  Australia   129.8230
# 639  New South Wales        AUS  Australia     3.0150
# 640  New South Wales        AUS  Australia  2448.7276
# 641  New South Wales        AUS  Australia     1.9786
#
#                                             LOCI_URI21  \
# 0    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 3    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 4    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# ..                                                 ...
# 637  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 638  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 639  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 640  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 641  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                               geometry  \
# 0    POLYGON ((150.92449 -33.74982, 150.92363 -33.7...
# 1    POLYGON ((151.09871 -33.97058, 151.09831 -33.9...
# 2    POLYGON ((151.67626 -32.96495, 151.67632 -32.9...
# 3    POLYGON ((150.87205 -33.68960, 150.87232 -33.6...
# 4    POLYGON ((150.97070 -33.75927, 150.97072 -33.7...
# ..                                                 ...
# 637  MULTIPOLYGON (((150.94709 -34.46452, 150.94712...
# 638  POLYGON ((150.94080 -34.04002, 150.94089 -34.0...
# 639  POLYGON ((151.06148 -33.88297, 151.05884 -33.8...
# 640  POLYGON ((150.34697 -33.14449, 150.34694 -33.1...
# 641  POLYGON ((151.23776 -33.89064, 151.23874 -33.8...
#
#                               city 65years_and_over  total  elderly_ratio
# 0       Lalor Park - Kings Langley             4029  25373       0.158791
# 1    South Hurstville - Blakehurst             4304  25259       0.170395
# 2             Charlestown - Dudley             4530  25254       0.179378
# 3                Schofields - East              952  25130       0.037883
# 4            Baulkham Hills - East             4031  24726       0.163027
# ..                             ...              ...    ...            ...
# 637         Port Kembla Industrial                0      5       0.000000
# 638       Holsworthy Military Area                0      5       0.000000
# 639              Rookwood Cemetery                0      3       0.000000
# 640          Wollangambe - Wollemi                0      0       0.000000
# 641                Centennial Park                0      0       0.000000
#
# [642 rows x 21 columns]

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2_NSW.plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua_population.plot(column = 'total', edgecolor = 'black', cmap = 'rainbow', linewidth = 0, legend = True, ax = ax)

plt.title('Total Population in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Total Population in NSW')

# %%
# create a new column 'Total_Rank'
df_population['total_rank'] = df_population.index + 1

# calculate the log value
with np.errstate(divide='ignore'):
    df_population['total_population_log'] = np.where((df_population['total'] > 0), np.log10(df_population['total']), 0)

df_population['total_rank_log'] = np.log10(df_population['total_rank'])
print(len(df_population))
df_population
# Out:
# 642
#                               city  65years_and_over  total  elderly_ratio  \
# 0       Lalor Park - Kings Langley              4029  25373       0.158791
# 1    South Hurstville - Blakehurst              4304  25259       0.170395
# 2             Charlestown - Dudley              4530  25254       0.179378
# 3                Schofields - East               952  25130       0.037883
# 4            Baulkham Hills - East              4031  24726       0.163027
# ..                             ...               ...    ...            ...
# 637         Port Kembla Industrial                 0      5       0.000000
# 638       Holsworthy Military Area                 0      5       0.000000
# 639              Rookwood Cemetery                 0      3       0.000000
# 640          Wollangambe - Wollemi                 0      0       0.000000
# 641                Centennial Park                 0      0       0.000000
#
#      total_rank  total_population_log  total_rank_log
# 0             1              4.404372        0.000000
# 1             2              4.402416        0.301030
# 2             3              4.402330        0.477121
# 3             4              4.400192        0.602060
# 4             5              4.393154        0.698970
# ..          ...                   ...             ...
# 637         638              0.698970        2.804821
# 638         639              0.698970        2.805501
# 639         640              0.477121        2.806180
# 640         641              0.000000        2.806858
# 641         642              0.000000        2.807535
#
# [642 rows x 7 columns]

# %%
# least squares polynomial fit
model = np.polyfit(df_population['total_population_log'], df_population['total_rank_log'], 1)
print(model)
# Out:
# [-0.34910754  3.76069578]

# %%
sns.regplot(data = df_population, x = df_population['total_population_log'], y = df_population['total_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %% [markdown]
# ## 1-2: Rank for elderly population

# %% [markdown]
# Get the total for age over 65

# %%
df_population = df_population.sort_values('65years_and_over', ascending = False)

# reset index after sorting
df_population = df_population.reset_index(drop = True)

# create a new column 'Elderly_Rank'
df_population['elderly_rank'] = df_population.index + 1

# calculate the log value
with np.errstate(divide='ignore'):
    df_population['elderly_population_log'] = np.where((df_population['65years_and_over'] > 0), np.log10(df_population['65years_and_over']), 0)
df_population['elderly_rank_log'] = np.log10(df_population['elderly_rank'])
df_population.head()
# Out:
#                            city  65years_and_over  total  elderly_ratio  \
# 0          Nelson Bay Peninsula              7654  21972       0.348352
# 1       Laurieton - Bonny Hills              7030  18484       0.380329
# 2  Umina - Booker Bay - Patonga              6661  24697       0.269709
# 3                       Ballina              6464  18629       0.346986
# 4         Port Macquarie - West              6297  21147       0.297773
#
#    total_rank  total_population_log  total_rank_log  elderly_rank  \
# 0          46              4.341870        1.662758             1
# 1         126              4.266796        2.100371             2
# 2           6              4.392644        0.778151             3
# 3         123              4.270190        2.089905             4
# 4          65              4.325249        1.812913             5
#
#    elderly_population_log  elderly_rank_log
# 0                3.883888          0.000000
# 1                3.846955          0.301030
# 2                3.823539          0.477121
# 3                3.810501          0.602060
# 4                3.799134          0.698970

# %% [markdown]
# Bar comparison

# %%
fig, ax = plt.subplots(figsize=(16,10))
plt.bar(df_population['city'], df_population['65years_and_over'])

plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2_NSW.plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua_population.plot(column = '65years_and_over', edgecolor = 'black', cmap = 'rainbow', linewidth = 0, legend = True, ax = ax)

plt.title('Elderly in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Elderly in NSW')

# %%
# least squares polynomial fit
model = np.polyfit(df_population['elderly_rank_log'], df_population['elderly_population_log'], 1)
print(model)
# Out:
# [-0.69536625  4.85392029]

# %%
sns.regplot(data = df_population, x = df_population['elderly_population_log'], y = df_population['elderly_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %% [markdown]
# ## 1-3 Elderly Population vs Total Population

# %%
df_population = df_population.sort_values('elderly_ratio', ascending = False)

# # reset index after sorting
df_population = df_population.reset_index(drop = True)

# # create a new column 'elderly_ratio_rank'
df_population['elderly_ratio_rank'] = df_population.index + 1

# # calculate the log value
with np.errstate(divide='ignore'):
    df_population['elderly_ratio_population_log'] = np.where((df_population['elderly_ratio'] > 0), np.log10(df_population['elderly_ratio']), 0)
df_population['elderly_ratio_rank_log'] = np.log10(df_population['elderly_ratio_rank'])
df_population.head(3)
# Out:
#                        city  65years_and_over  total  elderly_ratio  \
# 0  Tea Gardens - Hawks Nest              3006   5804       0.517919
# 1    Port Botany Industrial                 3      6       0.500000
# 2         Deua - Wadbilliga                20     43       0.465116
#
#    total_rank  total_population_log  total_rank_log  elderly_rank  \
# 0         544              3.763727        2.735599           145
# 1         637              0.778151        2.804139           629
# 2         625              1.633468        2.795880           624
#
#    elderly_population_log  elderly_rank_log  elderly_ratio_rank  \
# 0                3.477989          2.161368                   1
# 1                0.477121          2.798651                   2
# 2                1.301030          2.795185                   3
#
#    elderly_ratio_population_log  elderly_ratio_rank_log
# 0                     -0.285738                0.000000
# 1                     -0.301030                0.301030
# 2                     -0.332438                0.477121

# %%
fig, ax = plt.subplots(figsize=(16,10))
plt.bar(df_population['city'], df_population['elderly_ratio'])

plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2_NSW.plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sua_population.plot(column = 'elderly_ratio', edgecolor = 'black', cmap = 'rainbow', linewidth = 0, legend = True, ax = ax)

plt.title('Elderly Ratio in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Elderly Ratio in NSW')

# %%
# least squares polynomial fit
model = np.polyfit(df_population['elderly_ratio_rank_log'], df_population['elderly_ratio_population_log'], 1)
print(model)
# Out:
# [-0.31274539 -0.00412161]

# %%
sns.regplot(data = df_population, x = df_population['elderly_ratio_population_log'], y = df_population['elderly_ratio_rank_log'],
            label='y = ' + str(round(model[0],4)) + 'x' + str(round(model[1],4)))
plt.legend()
plt.show()

# %% [markdown]
# ## 2: Social facilities rank

# %% [markdown]
# # Hospitals

# %% [markdown]
# Get hospital list from https://www.health.gov.au/resources/publications/list-of-declared-hospitals

# %%
df_hospital = pd.read_excel('list-of-declared-hospitals.xlsx', header = 0, names = ['type', 'state', 'name', 'provider_number', 'address', 'suburb', 'Postcode', 'Second-tier Eligible', 'Second-tier Expiry Date', 'Second-tier Category', 'Circular_#', 'neo-natal_facility']);
df_hospital = df_hospital.loc[df_hospital['state'] == 'NSW']
df_hospital = df_hospital.drop(columns=['type', 'state', 'name', 'provider_number', 'suburb', 'Postcode', 'Second-tier Eligible', 'Second-tier Expiry Date', 'Second-tier Category', 'Circular_#', 'neo-natal_facility'])
df_hospital = df_hospital.reset_index(drop = True)
df_hospital.head()
# Out:
#                  address
# 0   14 KENSINGTON STREET
# 1          4 BAKER COURT
# 2       201 BORELLA ROAD
# 3  1125 PEMBERTON STREET
# 4       15 BOWDEN STREET

# %%
def get_coordinates(address):
    location = geolocator.geocode(address)
    if location:
        return pd.Series([location.latitude, location.longitude])
    else:
        return pd.Series([None, None])

# %%
df_hospital[['lat', 'lon']] = df_hospital['address'].apply(lambda x: get_coordinates(x))
print(len(df_hospital))
print(df_hospital.head())
# Out:
# 419
#                  address        lat         lon
# 0   14 KENSINGTON STREET -33.965202  151.134877
# 1          4 BAKER COURT  40.597530  -73.653075
# 2       201 BORELLA ROAD -36.077223  146.938523
# 3  1125 PEMBERTON STREET -36.074120  146.896020
# 4       15 BOWDEN STREET -33.904791  151.196103

# %% [markdown]
# # Aged care service

# %% [markdown]
# Aged care service list: 30 June 2022
# https://www.gen-agedcaredata.gov.au/Resources/Access-data/2022/October/Aged-care-service-list-30-June-2022

# %%
df_age_care = pd.read_csv('Cleaned_Aged care service list in NSW_30-June-2022.csv', header = 0);
age_care = pd.DataFrame()
age_care['lat'] = df_age_care['Latitude']
age_care['lon'] = df_age_care['Longitude']
print(len(age_care))
age_care.head(3)
# Out:
# 1755
#          lat         lon
# 0 -35.442764  149.805407
# 1 -36.075401  146.890896
# 2 -29.961591  146.864313

# %% [markdown]
# # Other Healthcare

# %% [markdown]
# https://wiki.openstreetmap.org/wiki/Key:amenity#Healthcare
#
# https://www.openstreetmap.org/relation/2316593
#
# area["ISO3166-2"="AU-NSW"][admin_level=4] is the same as area(3602316593)

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="clinic"](area);
 way["amenity"="clinic"](area);
 rel["amenity"="clinic"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
clinics = data['elements']
print(len(clinics))
# Out:
# 263

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="dentist"](area);
 way["amenity"="dentist"](area);
 rel["amenity"="dentist"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
dentists = data['elements']
print(len(dentists))
# Out:
# 273

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="nursing_home"](area);
 way["amenity"="nursing_home"](area);
 rel["amenity"="nursing_home"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
nursing_homes = data['elements']
len(data)
# Out:
# 4

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="pharmacy"](area);
 way["amenity"="pharmacy"](area);
 rel["amenity"="pharmacy"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
pharmacys = data['elements']
print(len(pharmacys))
# Out:
# 682

# %%
overpass_query = """
[out:json];
area(3602316593);
(node["amenity"="social_facility"](area);
 way["amenity"="social_facility"](area);
 rel["amenity"="social_facility"](area);
);
out center;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()
social_facilities = data['elements']
print(len(social_facilities))
# Out:
# 103

# %%
other_healthcare = clinics + dentists + nursing_homes + pharmacys + social_facilities
print(len(other_healthcare))
# Out:
# 1340

# %% [markdown]
# # All Healthcare Services

# %%
df_hospital = df_hospital.drop(columns=['address'])
df_hospital.head()
# Out:
#          lat         lon
# 0 -33.965202  151.134877
# 1  40.597530  -73.653075
# 2 -36.077223  146.938523
# 3 -36.074120  146.896020
# 4 -33.904791  151.196103

# %%
rows = [{'lat': item['lat'], 'lon': item['lon']} for item in other_healthcare]

# Create a DataFrame from the extracted values
df_all_healthcare = pd.DataFrame(rows)
print(len(df_all_healthcare))
df_all_healthcare.head()
# Out:
# 1340
#          lat         lon
# 0 -33.889157  151.275200
# 1 -33.889556  151.271111
# 2 -33.888995  151.270199
# 3 -33.829431  151.218038
# 4 -33.751564  151.287806

# %%
df_all_healthcare = pd.concat([df_all_healthcare, df_hospital], ignore_index=True)
df_all_healthcare = pd.concat([df_all_healthcare, age_care], ignore_index=True)
print(len(df_all_healthcare))
df_all_healthcare.head()
# Out:
# 3873
#          lat         lon                     geometry
# 0 -33.889157  151.275200  POINT (151.27520 -33.88916)
# 1 -33.889556  151.271111  POINT (151.27111 -33.88956)
# 2 -33.888995  151.270199  POINT (151.27020 -33.88900)
# 3 -33.829431  151.218038  POINT (151.21804 -33.82943)
# 4 -33.751564  151.287806  POINT (151.28781 -33.75156)

# %%
df_all_healthcare = df_all_healthcare.drop_duplicates(subset=['lat', 'lon'])
print(len(df_all_healthcare))
df_all_healthcare.head()
# Out:
# 3043
#          lat         lon                     geometry
# 0 -33.889157  151.275200  POINT (151.27520 -33.88916)
# 1 -33.889556  151.271111  POINT (151.27111 -33.88956)
# 2 -33.888995  151.270199  POINT (151.27020 -33.88900)
# 3 -33.829431  151.218038  POINT (151.21804 -33.82943)
# 4 -33.751564  151.287806  POINT (151.28781 -33.75156)

# %%
gdf_all_healthcare = gpd.GeoDataFrame(df_all_healthcare,
                               geometry = gpd.points_from_xy(df_all_healthcare.lon, df_all_healthcare.lat))

gdf_all_healthcare.to_file('HealthcareLocationInNSW.geojson', driver='GeoJSON')

# %%
gdf_all_healthcare = gpd.read_file('HealthcareLocationInNSW.geojson')
print(len(gdf_all_healthcare))
gdf_all_healthcare.head(3)
# Out:
# 3043
#          lat         lon                     geometry
# 0 -33.889157  151.275200  POINT (151.27520 -33.88916)
# 1 -33.889556  151.271111  POINT (151.27111 -33.88956)
# 2 -33.888995  151.270199  POINT (151.27020 -33.88900)

# %%
print(gdf_all_healthcare.crs)
print(gdf_sa2_NSW.crs)
# Out:
# EPSG:4326
# EPSG:7844

# %%
gdf_all_healthcare = gdf_all_healthcare.to_crs(gdf_sa2_NSW.crs)

print(gdf_all_healthcare.crs)
print(gdf_sa2_NSW.crs)
# Out:
# EPSG:7844
# EPSG:7844

# %%
gdf_all_healthcare_GS = gpd.sjoin(gdf_all_healthcare, gdf_sa2_NSW)

print(gdf_all_healthcare.shape)
print(gdf_sa2_NSW.shape)
print(len(gdf_all_healthcare_GS))
print(type(gdf_all_healthcare_GS))
gdf_all_healthcare_GS.head()
# Out:
# (3043, 3)
# (642, 17)
# 2901
# <class 'geopandas.geodataframe.GeoDataFrame'>
#            lat         lon                     geometry  index_right  \
# 0   -33.889157  151.275200  POINT (151.27520 -33.88916)          371
# 1   -33.889556  151.271111  POINT (151.27111 -33.88956)          371
# 2   -33.888995  151.270199  POINT (151.27020 -33.88900)          371
# 98  -33.885255  151.274439  POINT (151.27444 -33.88526)          371
# 155 -33.887218  151.271936  POINT (151.27194 -33.88722)          371
#
#     SA2_CODE21                 SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  \
# 0    118011340  Bondi Beach - North Bondi          0  No change      11801
# 1    118011340  Bondi Beach - North Bondi          0  No change      11801
# 2    118011340  Bondi Beach - North Bondi          0  No change      11801
# 98   118011340  Bondi Beach - North Bondi          0  No change      11801
# 155  118011340  Bondi Beach - North Bondi          0  No change      11801
#
#                   SA3_NAME21 SA4_CODE21                SA4_NAME21 GCC_CODE21  \
# 0    Eastern Suburbs - North        118  Sydney - Eastern Suburbs      1GSYD
# 1    Eastern Suburbs - North        118  Sydney - Eastern Suburbs      1GSYD
# 2    Eastern Suburbs - North        118  Sydney - Eastern Suburbs      1GSYD
# 98   Eastern Suburbs - North        118  Sydney - Eastern Suburbs      1GSYD
# 155  Eastern Suburbs - North        118  Sydney - Eastern Suburbs      1GSYD
#
#          GCC_NAME21 STE_CODE21       STE_NAME21 AUS_CODE21 AUS_NAME21  \
# 0    Greater Sydney          1  New South Wales        AUS  Australia
# 1    Greater Sydney          1  New South Wales        AUS  Australia
# 2    Greater Sydney          1  New South Wales        AUS  Australia
# 98   Greater Sydney          1  New South Wales        AUS  Australia
# 155  Greater Sydney          1  New South Wales        AUS  Australia
#
#      AREASQKM21                                         LOCI_URI21
# 0        2.4604  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1        2.4604  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2        2.4604  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 98       2.4604  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 155      2.4604  http://linked.data.gov.au/dataset/asgsed3/SA2/...

# %%
fig, ax = plt.subplots(figsize = (12,12))

gdf_sa2_NSW.plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_all_healthcare_GS.plot(color = '#FF9300', markersize = 5, ax = ax, label = 'Healthcare')

plt.title('Healthcare in the NSW', fontsize = 15)
plt.legend(fontsize = 15)

plt.show()

# %% [markdown]
# Now we try to get the city for the coordinations

# %%
sum_counts = gdf_all_healthcare_GS['SA2_NAME21'].value_counts()

df_all_healthcare_in_city = pd.DataFrame()
df_all_healthcare_in_city['SA2_NAME21'] = gdf_all_healthcare_GS['SA2_NAME21']
df_all_healthcare_in_city['sum_counts'] = df_all_healthcare_in_city['SA2_NAME21'].map(sum_counts)
df_all_healthcare_in_city = df_all_healthcare_in_city.drop_duplicates(subset=['SA2_NAME21'])
# Reset the index of the DataFrame
print(len(df_all_healthcare_in_city))
print(type(df_all_healthcare_in_city))
df_all_healthcare_in_city.head()
# Out:
# 551
# <class 'pandas.core.frame.DataFrame'>
#                   SA2_NAME21  sum_counts
# 0  Bondi Beach - North Bondi          13
# 3   Neutral Bay - Kirribilli          11
# 4            Dee Why - North           5
# 5                Goonellabah           7
# 6       Charlestown - Dudley           5

# %%
gdf_sa2_healthcare = pd.merge(gdf_sa2_NSW, df_all_healthcare_in_city, 
                          left_on = 'SA2_NAME21', right_on = 'SA2_NAME21',
                          how = 'right')
print(len(gdf_sa2_healthcare))
gdf_sa2_healthcare
# Out:
# 551
#     SA2_CODE21                 SA2_NAME21 CHG_FLAG21    CHG_LBL21 SA3_CODE21  \
# 0    118011340  Bondi Beach - North Bondi          0    No change      11801
# 1    121041416   Neutral Bay - Kirribilli          0    No change      12104
# 2    122031695            Dee Why - North          1          New      12203
# 3    112021246                Goonellabah          0    No change      11202
# 4    111011208       Charlestown - Dudley          0    No change      11101
# ..         ...                        ...        ...          ...        ...
# 546  125031486      Smithfield Industrial          0    No change      12503
# 547  127021514               Edensor Park          0    No change      12702
# 548  123011698               Currans Hill          1          New      12301
# 549  117011634                  Eastlakes          1          New      11701
# 550  101061542             Yass Surrounds          3  Name change      10106
#
#                        SA3_NAME21 SA4_CODE21  \
# 0         Eastern Suburbs - North        118
# 1           North Sydney - Mosman        121
# 2                       Warringah        122
# 3    Richmond Valley - Hinterland        112
# 4           Lake Macquarie - East        111
# ..                            ...        ...
# 546        Merrylands - Guildford        125
# 547                     Fairfield        127
# 548                        Camden        123
# 549                        Botany        117
# 550                  Young - Yass        101
#
#                             SA4_NAME21 GCC_CODE21      GCC_NAME21 STE_CODE21  \
# 0             Sydney - Eastern Suburbs      1GSYD  Greater Sydney          1
# 1    Sydney - North Sydney and Hornsby      1GSYD  Greater Sydney          1
# 2            Sydney - Northern Beaches      1GSYD  Greater Sydney          1
# 3                     Richmond - Tweed      1RNSW     Rest of NSW          1
# 4         Newcastle and Lake Macquarie      1RNSW     Rest of NSW          1
# ..                                 ...        ...             ...        ...
# 546                Sydney - Parramatta      1GSYD  Greater Sydney          1
# 547                Sydney - South West      1GSYD  Greater Sydney          1
# 548          Sydney - Outer South West      1GSYD  Greater Sydney          1
# 549      Sydney - City and Inner South      1GSYD  Greater Sydney          1
# 550                     Capital Region      1RNSW     Rest of NSW          1
#
#           STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 0    New South Wales        AUS  Australia      2.4604
# 1    New South Wales        AUS  Australia      2.2116
# 2    New South Wales        AUS  Australia      2.0816
# 3    New South Wales        AUS  Australia     25.2269
# 4    New South Wales        AUS  Australia     22.2795
# ..               ...        ...        ...         ...
# 546  New South Wales        AUS  Australia      4.3017
# 547  New South Wales        AUS  Australia      3.0955
# 548  New South Wales        AUS  Australia      7.0704
# 549  New South Wales        AUS  Australia      3.1149
# 550  New South Wales        AUS  Australia   5680.5696
#
#                                             LOCI_URI21  \
# 0    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 3    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 4    http://linked.data.gov.au/dataset/asgsed3/SA2/...
# ..                                                 ...
# 546  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 547  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 548  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 549  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 550  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                               geometry  sum_counts
# 0    POLYGON ((151.26933 -33.88297, 151.26955 -33.8...          13
# 1    POLYGON ((151.21394 -33.83111, 151.21434 -33.8...          11
# 2    POLYGON ((151.29857 -33.75119, 151.29842 -33.7...           5
# 3    POLYGON ((153.30666 -28.81170, 153.30682 -28.8...           7
# 4    POLYGON ((151.67626 -32.96495, 151.67632 -32.9...           5
# ..                                                 ...         ...
# 546  POLYGON ((150.93644 -33.83552, 150.93654 -33.8...           1
# 547  POLYGON ((150.86791 -33.87757, 150.86811 -33.8...           1
# 548  POLYGON ((150.74961 -34.03870, 150.74633 -34.0...           1
# 549  POLYGON ((151.19996 -33.92614, 151.19906 -33.9...           1
# 550  POLYGON ((148.35936 -34.85221, 148.35660 -34.8...           1
#
# [551 rows x 18 columns]

# %%
fig, ax = plt.subplots(figsize=(16,10))
gdf_sa2_NSW.plot(color = '#EDF2F4', edgecolor = 'black', linewidth = 0.5, alpha = 0.7, ax = ax)
gdf_sa2_healthcare.plot(column = 'sum_counts', cmap = 'rainbow', linewidth = 0, legend = True, ax = ax)

plt.title('Healthcare accessibility in NSW', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Healthcare accessibility in NSW')
